# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import os
import torch
components = ['Q', 'K', 'V']
for i in components:
    
    path = f'../atten_exp/saved_attn_scores/facebook/opt-350M/{i.lower()}_merged_attn_weights_layer10.pt'
    attn_weights = torch.load(path)
    print(attn_weights.shape)
    q = attn_weights.norm(dim=1).squeeze().cpu().detach().numpy()
    # Create the heatmap
    plt.figure(figsize=(5, 4))  # Adjust the figure size for better readability
    sns.heatmap(
        q.T, 
        cmap="coolwarm",  # Use a blue-red diverging colormap
        vmin=0, vmax=70,  # Set color range to match the bar
        center=0,  # Center the colormap around 0
    )

    # Add titles and axis labels
    plt.title(f"Embedding Vector of {i} (Layer 20)", fontsize=14)
    plt.xlabel("Number of Head", fontsize=12)
    plt.ylabel("Dim", fontsize=12)
    plt.xticks(fontsize=10)
    plt.yticks(fontsize=10)


    output_folder = "appendix"
    os.makedirs(output_folder, exist_ok=True)  # Ensure the folder exists
    output_file = os.path.join(output_folder, f"OPT_{i}_attention_map_layer_10.pdf")
    plt.savefig(output_file, format="pdf",bbox_inches='tight')
    plt.show()
# Out:
# torch.Size([1, 74, 16, 64])
# torch.Size([1, 74, 16, 64])
# torch.Size([1, 74, 16, 64])

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import os
import torch
components = ['Q', 'K', 'V']
for i in components:
    
    path = f'../atten_exp/saved_attn_scores/meta-llama/Meta-Llama-3-8B-Instruct/{i.lower()}_merged_attn_weights_layer10.pt'
    attn_weights = torch.load(path)
    print(attn_weights.shape)


    q = attn_weights.norm(dim=1).squeeze().cpu().detach().numpy()
    q = q[:, :64]
    # Create the heatmap
    plt.figure(figsize=(5, 4))  # Adjust the figure size for better readability
    sns.heatmap(
        q.T, 
        cmap="coolwarm",  # Use a blue-red diverging colormap
        vmin=0, vmax=70,  # Set color range to match the bar
        center=0,  # Center the colormap around 0
    )


    # Add titles and axis labels
    plt.title(f"Embedding Vector of {i} (Layer 10)", fontsize=14)
    plt.xlabel("Number of Head", fontsize=12)
    plt.ylabel("Dim", fontsize=12)
    plt.xticks(fontsize=10)
    plt.yticks(fontsize=10)


    output_folder = "appendix"
    os.makedirs(output_folder, exist_ok=True)  # Ensure the folder exists
    output_file = os.path.join(output_folder, f"Llama3_{i}_attention_map_layer_10.pdf")
    plt.savefig(output_file, format="pdf",bbox_inches='tight')
    plt.show()
# Out:
# torch.Size([1, 130, 32, 128])
# torch.Size([1, 130, 8, 128])
# torch.Size([1, 130, 8, 128])

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import os
import torch
components = ['Q', 'K', 'V']
for i in components:
    
    path = f'../mj939/atten_exp/saved_attn_scores/Qwen/Qwen2.5-7B-Instruct/{i.lower()}_merged_attn_weights_layer10.pt'
    attn_weights = torch.load(path)
    print(attn_weights.shape)
    q = attn_weights.norm(dim=1).squeeze().cpu().detach().numpy()
    q = q[:, :64]
    # Create the heatmap
    plt.figure(figsize=(5, 4))  # Adjust the figure size for better readability
    sns.heatmap(
        q.T, 
        cmap="coolwarm",  # Use a blue-red diverging colormap
        vmin=0, vmax=70,  # Set color range to match the bar
        center=0,  # Center the colormap around 0
    )

    # Add titles and axis labels
    plt.title(f"Embedding Vector of {i} (Layer 10)", fontsize=14)
    plt.xlabel("Number of Head", fontsize=12)
    plt.ylabel("Dim", fontsize=12)
    plt.xticks(fontsize=10)
    plt.yticks(fontsize=10)


    output_folder = "appendix"
    os.makedirs(output_folder, exist_ok=True)  # Ensure the folder exists
    output_file = os.path.join(output_folder, f"Qwen_{i}_attention_map_layer_10.pdf")
    plt.savefig(output_file, format="pdf",bbox_inches='tight')
    plt.show()
# Out:
# torch.Size([1, 395, 28, 128])
# torch.Size([1, 395, 28, 128])
# torch.Size([1, 395, 28, 128])

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import os
import torch
components = ['Q', 'K', 'V']
for i in components:
    
    path = f'../atten_exp/saved_attn_scores/mistralai/Mistral-7B-Instruct-v0.3/{i.lower()}_merged_attn_weights_layer10.pt'
    attn_weights = torch.load(path)
    print(attn_weights.shape)
    q = attn_weights.norm(dim=1).squeeze().cpu().detach().numpy()
    q = q[:, :64]
    # Create the heatmap
    plt.figure(figsize=(5, 4))  # Adjust the figure size for better readability
    sns.heatmap(
        q.T, 
        cmap="coolwarm",  # Use a blue-red diverging colormap
        vmin=0, vmax=70,  # Set color range to match the bar
        center=0,  # Center the colormap around 0
    )

    # Add titles and axis labels
    plt.title(f"Embedding Vector of {i} (Layer 10)", fontsize=14)
    plt.xlabel("Number of Head", fontsize=12)
    plt.ylabel("Dim", fontsize=12)
    plt.xticks(fontsize=10)
    plt.yticks(fontsize=10)


    output_folder = "appendix"
    os.makedirs(output_folder, exist_ok=True)  # Ensure the folder exists
    output_file = os.path.join(output_folder, f"Mistral_{i}_attention_map_layer_10.pdf")
    plt.savefig(output_file, format="pdf",bbox_inches='tight')
    plt.show()
# Out:
# torch.Size([1, 117, 32, 128])
# torch.Size([1, 117, 32, 128])
# torch.Size([1, 117, 32, 128])

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import os
import torch
components = ['Q', 'K', 'V']
for i in components:
   
    path = f'../atten_exp/saved_attn_scores/Qwen/Qwen2-VL-7B-Instruct/{i.lower()}_merged_vision_attn_weights_layer20.pt'
    attn_weights = torch.load(path)
    print(attn_weights.shape)
    q = attn_weights.norm(dim=0).squeeze().cpu().detach().numpy()
    print(q.shape)
    q = q[:, :40]
    # Create the heatmap
    plt.figure(figsize=(5, 4))  # Adjust the figure size for better readability
    sns.heatmap(
        q.T, 
        cmap="coolwarm",  # Use a blue-red diverging colormap
        vmin=0, vmax=200,  # Set color range to match the bar
        center=0,  # Center the colormap around 0
    )

    # Add titles and axis labels
    plt.title(f"Embedding Vector of {i} (Layer 10)", fontsize=14)
    plt.xlabel("Number of Head", fontsize=12)
    plt.ylabel("Dim", fontsize=12)
    plt.xticks(fontsize=10)
    plt.yticks(fontsize=10)


    output_folder = "appendix"
    os.makedirs(output_folder, exist_ok=True)  # Ensure the folder exists
    output_file = os.path.join(output_folder, f"Qwen2VL_{i}_Vision_attention_map_layer_10.pdf")
    plt.savefig(output_file, format="pdf",bbox_inches='tight')
    plt.show()
# Out:
# torch.Size([6072, 16, 80])
# (16, 80)
# torch.Size([6072, 16, 80])
# (16, 80)
# torch.Size([6072, 16, 80])
# (16, 80)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import os
import torch
components = ['Q', 'K', 'V']
for i in components:
   
    path = f'../atten_exp/saved_attn_scores/Qwen/Qwen2-VL-7B-Instruct/{i.lower()}_merged_attn_weights_layer10.pt'
    attn_weights = torch.load(path)
    print(attn_weights.shape)
    q = attn_weights.norm(dim=2).squeeze().cpu().detach().numpy()
    print(q.shape)
    q = q[:, :64]
    # Create the heatmap
    plt.figure(figsize=(5, 4))  # Adjust the figure size for better readability
    sns.heatmap(
        q.T, 
        cmap="coolwarm",  # Use a blue-red diverging colormap
        vmin=0, vmax=200,  # Set color range to match the bar
        center=0,  # Center the colormap around 0
    )

    # Add titles and axis labels
    plt.title(f"Embedding Vector of {i} (Layer 10)", fontsize=14)
    plt.xlabel("Number of Head", fontsize=12)
    plt.ylabel("Dim", fontsize=12)
    plt.xticks(fontsize=10)
    plt.yticks(fontsize=10)


    output_folder = "appendix"
    os.makedirs(output_folder, exist_ok=True)  # Ensure the folder exists
    output_file = os.path.join(output_folder, f"Qwen2VL_{i}_attention_map_layer_10.pdf")
    plt.savefig(output_file, format="pdf",bbox_inches='tight')
    plt.show()
# Out:
# torch.Size([1, 28, 1543, 128])
# (28, 128)
# torch.Size([1, 28, 1543, 128])
# (28, 128)
# torch.Size([1, 28, 1543, 128])
# (28, 128)
